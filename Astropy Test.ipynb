# %%
import astropy as ap
from astropy.io import fits

# %%
ap.test()
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 2.7.13, pytest-3.2.1, py-1.4.34, pluggy-0.4.0
#
# Running tests with Astropy version 2.0.3.
# Running tests in anaconda2/lib/python2.7/site-packages/astropy.
#
# Date: 2018-01-10T13:53:01
#
# Platform: Darwin-16.6.0-x86_64-i386-64bit
#
# Executable: /Users/sharoniegreenblatt/anaconda2/bin/python
#
# Full Python Version:
# 2.7.13 |Anaconda custom (64-bit)| (default, Sep 21 2017, 17:38:20)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
#
# encodings: sys: ascii, locale: UTF-8, filesystem: utf-8, unicode bits: 15
# byteorder: little
# float info: dig: 15, mant_dig: 15
#
# Numpy: 1.13.3
# Scipy: 0.19.1
# Matplotlib: 2.0.2
# h5py: 2.7.0
# Pandas: 0.20.3
# Cython: 0.26.1
# Using Astropy options: remote_data: none.
#
# rootdir: /Users/sharoniegreenblatt, inifile:
# collected 12717 items
#
# ...

# %%
hdulist = fits.open('spec-4055-55359-0001.fits')
hudlist2 = fits.open('spec-4055-55359-0027.fits')

# %%
hdulist.info()
# Out:
# Filename: spec-4055-55359-0001.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     116   ()
#   1  COADD         1 BinTableHDU     26   4605R x 8C   [E, E, E, J, J, E, E, E]
# ...

# %%
print hudlist2.info()
# Out:
# Filename: spec-4055-55359-0027.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     116   ()
#   1  COADD         1 BinTableHDU     26   4605R x 8C   [E, E, E, J, J, E, E, E]
# ...

# %%
scidata = hdulist[1].data
scidata2 = hdulist[2].data

# %%
print scidata[0]
print scidata2[0]
# Out:
# (15.851429, 3.5529001, 0.0098913033, 0, 71303168, 1.7416389, 5.1214852, 11.854057)
# (4.474122, 3.5529001, 0.014870082, 0, 71303168, 1.6576539, 1.1927017, 0.51677847)

# %% [markdown]
# ## PLACE TO FIND CLASSIFICATION
#
# Look for the data row 2, column 0, 'SUBCLASS'

# %%
print hdulist[2].data[0]['SUBCLASS']
# Out:
# F3/F5V (30743)

# %%
cols = hdulist[1].columns
cols.info()
# Out:
# name:
#     ['flux', 'loglam', 'ivar', 'and_mask', 'or_mask', 'wdisp', 'sky', 'model']
# format:
#     ['E', 'E', 'E', 'J', 'J', 'E', 'E', 'E']
# unit:
#     ['', '', '', '', '', '', '', '']
# null:
#     ['', '', '', '', '', '', '', '']
# bscale:
#     ['', '', '', '', '', '', '', '']
# bzero:
#     ['', '', '', '', '', '', '', '']
# disp:
#     ['', '', '', '', '', '', '', '']
# start:
#     ['', '', '', '', '', '', '', '']
# dim:
#     ['', '', '', '', '', '', '', '']

# %%
cols = hdulist[2].columns
cols.info
# Out:
# <bound method ColDefs.info of ColDefs(
#     name = 'PROGRAMNAME'; format = '4A'
#     name = 'CHUNK'; format = '7A'
#     name = 'PLATEQUALITY'; format = '4A'
#     name = 'PLATESN2'; format = 'E'
#     name = 'DEREDSN2'; format = 'E'
#     name = 'PRIMTARGET'; format = 'J'
#     name = 'SECTARGET'; format = 'J'
#     name = 'LAMBDA_EFF'; format = 'E'
#     name = 'BLUEFIBER'; format = 'J'
#     name = 'ZOFFSET'; format = 'E'
#     name = 'XFOCAL'; format = 'E'
#     name = 'YFOCAL'; format = 'E'
#     name = 'BOSS_TARGET1'; format = 'K'
#     name = 'BOSS_TARGET2'; format = 'K'
#     name = 'ANCILLARY_TARGET1'; format = 'K'
#     name = 'ANCILLARY_TARGET2'; format = 'K'
#     name = 'SPECPRIMARY'; format = 'B'
#     name = 'SPECOBJ_ID'; format = 'J'
#     name = 'NSPECOBS'; format = 'I'
#     name = 'Z_PERSON'; format = 'E'
#     name = 'CLASS_PERSON'; format = 'J'
#     name = 'Z_CONF_PERSON'; format = 'J'
#     name = 'COMMENTS_PERSON'; format = '10A'
# ...
